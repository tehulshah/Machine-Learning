# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# ### EDA

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.shape
# Out:
# (918, 12)

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['HeartDisease'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
def plotting(var, num):
    plt.subplot(2, 2, num)
    sns.histplot(df[var], kde=True)

plotting('Age', 1)
plotting('RestingBP', 2)
plotting('Cholesterol', 3)
plotting('MaxHR', 4)
plt.tight_layout()
plt.show()

# %% [markdown]
# Here looking at the distribution of the numerical features, we can see that there are some outliers in RestingBP and Cholesterol with 0 values. As researched a person can't have 0 blood pressure or cholesterol level, so these are invalid values and we will be treating them as missing values. We will replace these 0 values with the mean of the respective columns.

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 0      172
# 254     11
# 220     10
# 223     10
# 204      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64

# %%
ch_mean = df.loc[df['Cholesterol'] != 0, 'Cholesterol'].mean()
df['Cholesterol'] = df['Cholesterol'].replace(0, ch_mean)
df['Cholesterol'].round(2)
# Out:
# 0      289.0
# 1      180.0
# 2      283.0
# 3      214.0
# 4      195.0
#        ...
# 913    264.0
# 914    193.0
# 915    131.0
# 916    236.0
# 917    175.0
# Name: Cholesterol, Length: 918, dtype: float64

# %%
restingbp_mean = df.loc[df['RestingBP'] != 0, 'RestingBP'].mean()
df['RestingBP'] = df['RestingBP'].replace(0, restingbp_mean)
df['RestingBP'].round(2)
# Out:
# 0      140.0
# 1      160.0
# 2      130.0
# 3      138.0
# 4      150.0
#        ...
# 913    110.0
# 914    144.0
# 915    130.0
# 916    130.0
# 917    138.0
# Name: RestingBP, Length: 918, dtype: float64

# %%
def plotting(var, num):
    plt.subplot(2, 2, num)
    sns.histplot(df[var], kde=True)

plotting('Age', 1)
plotting('RestingBP', 2)
plotting('Cholesterol', 3)
plotting('MaxHR', 4)
plt.tight_layout()
plt.show()

# %%
import sheryanalysis as sh
sh.analyze(df)
# Out:
# 🔍 Basic Analysis Report
# ------------------------------------------------------------
# 📏 Shape: (918, 12)
# 🧱 Columns: ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease']
#
# ✅ No null values found
#
# 🔠 Categorical Columns: ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'HeartDisease']
#
# 🔢 Numerical Columns: ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
# {'shape': (918, 12),
#  'columns': ['Age',
#   'Sex',
#   'ChestPainType',
#   'RestingBP',
#   'Cholesterol',
#   'FastingBS',
#   'RestingECG',
#   'MaxHR',
#   'ExerciseAngina',
#   'Oldpeak',
#   'ST_Slope',
#   'HeartDisease'],
#  'dtypes': {'Age': dtype('int64'),
#   'Sex': dtype('O'),
#   'ChestPainType': dtype('O'),
#   'RestingBP': dtype('float64'),
#   'Cholesterol': dtype('float64'),
#   'FastingBS': dtype('int64'),
#   'RestingECG': dtype('O'),
# ...

# %%
sns.countplot(x='Sex',hue='HeartDisease', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='ChestPainType',hue='HeartDisease', data=df)
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x='FastingBS',hue='HeartDisease', data=df)
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
# Using Box Plot to compare numerical and categorical variables together

sns.boxplot(x='HeartDisease', y='Cholesterol', data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x='HeartDisease', y='Age', data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### Data Preprocessing and cleaning

# %%
df_encode = pd.get_dummies(df, drop_first=True)
df_encode = df_encode.astype(int)
df_encode.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172        0             0
# 1   49        160          180          0    156        1             1
# 2   37        130          283          0     98        0             0
# 3   48        138          214          0    108        1             1
# 4   54        150          195          0    122        0             0
#
#    Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0      1                  1                  0                 0
# 1      0                  0                  1                 0
# 2      1                  1                  0                 0
# 3      0                  0                  0                 0
# 4      1                  0                  1                 0
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# ...

# %%
# Data Scaling

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

numercal_cols = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
scaled_data = scaler.fit_transform(df_encode[numercal_cols])
df_encode.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172        0             0
# 1   49        160          180          0    156        1             1
# 2   37        130          283          0     98        0             0
# 3   48        138          214          0    108        1             1
# 4   54        150          195          0    122        0             0
#
#    Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0      1                  1                  0                 0
# 1      0                  0                  1                 0
# 2      1                  1                  0                 0
# 3      0                  0                  0                 0
# 4      1                  0                  1                 0
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# ...
